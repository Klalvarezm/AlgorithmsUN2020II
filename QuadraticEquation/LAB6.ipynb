# %%
#Libraries
import math
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# *   **Name:** Kevin Leoanrdo Alvarez Mora
# *   **Group:** 2
# *   **Identification:** 1010228053
#
# # **Newton-Raphson Fractals and the Quadratic Equation:**
#
# ###    Newthon-Raphson is mathematical method established to find the roots of real and complex functions base on a series of terms obtained through the derivative of the a function and a set point, this methos consists in a series of iterations, yet can diverge from a point caotically due to its sensibility when handling the tangent in the derivatives.
#
# ### Each term on the series is given by the next formula.
# ![newtons-method-formula.png](data:image/png;base64,...)

# %% [markdown]
# # **1.Plots**
# Plot the following functions in an $x$ range that include that include the vertex and the roots (if there are roots).
#
#
#
# *   $y=x^2$

# %%
def f1(z): #original function 
    return z ** 2

x = np.linspace(-1.0,1.0,100) #set of points
fig, ax = plt.subplots() #Plot funtion
ax.plot(x,f1(x))  #Plot parameter by axis
ax.axhline(y=0, color='k') #Color of the horizontal line
ax.axvline(x=0, color='k') #Color of the horizontal line
ax.grid(True, which='both') #Sets of the plot ehre the grid is going to be displayed
plt.title('f(x)=x^2') #title of the plot
plt.xlabel('X') #label of the x-axis
plt.ylabel('f(x) = x^2') #label of the y-axis
# Out:
# Text(0, 0.5, 'f(x) = x^2')

# %% [markdown]
# *  $y=(x-1)^2$

# %%
def f2(z): #original function 
    return (x-1)**2

x = np.linspace(0,2.0,100) #set of points
fig, ax = plt.subplots() #Plot funtion
ax.plot(x,f2(x))  #Plot parameter by axis
ax.axhline(y=0, color='k') #Color of the horizontal line
ax.axvline(x=0, color='k') #Color of the horizontal line
ax.grid(True, which='both') #Sets of the plot ehre the grid is going to be displayed
plt.title('f(x)=(x-1)^2') #title of the plot
plt.xlabel('X') #label of the x-axis
plt.ylabel('f(x) = (x-1)^2') #label of the y-axis
# Out:
# Text(0, 0.5, 'f(x) = (x-1)^2')

# %% [markdown]
# *   $y=x^2-1$

# %%
def f3(z): #original function 
    return (z**2)-1

x = np.linspace(-1.0,1.0,100) #set of points
fig, ax = plt.subplots() #Plot funtion
ax.plot(x,f3(x))  #Plot parameter by axis
ax.axhline(y=0, color='k') #Color of the horizontal line
ax.axvline(x=0, color='k') #Color of the horizontal line
ax.grid(True, which='both') #Sets of the plot ehre the grid is going to be displayed
plt.title('f(x)=x^2 - 1') #title of the plot
plt.xlabel('X') #label of the x-axis
plt.ylabel('f(x) = x^2 - 1') #label of the y-axis
# Out:
# Text(0, 0.5, 'f(x) = x^2 - 1')

# %% [markdown]
# *   $y=x^2+1$

# %%
def f4(z): #original function 
    return (z**2)+1

x = np.linspace(-1.0,1.0,100) #set of points
fig, ax = plt.subplots() #Plot funtion
ax.plot(x,f3(x))  #Plot parameter by axis
ax.axhline(y=0, color='k') #Color of the horizontal line
ax.axvline(x=0, color='k') #Color of the horizontal line
ax.grid(True, which='both') #Sets of the plot ehre the grid is going to be displayed
plt.title('f(x)=x^2 + 1') #title of the plot
plt.xlabel('X') #label of the x-axis
plt.ylabel('f(x) = x^2 + 1') #label of the y-axis
# Out:
# Text(0, 0.5, 'f(x) = x^2 + 1')

# %% [markdown]
# # **2. Clasic and Po Shen Loh's Method**
#
# The Clasic method to solve quadratic equations depends on the discriminant of the formula to determine whether if the root is real or complex, although it isn't a hard method it is far from intuitive.
#
# ### $ax^2+bx+c$
#
# We obtain the roots by replacing values in this formula:
# # $x= \frac{-b\pm\sqrt{b^2-4ac}}{2a}$
#
# Po Shen Loh's method is based on a series of steps to find solutions to quadratic equations, using the standard quadratic equation:
#
# ### $ax^2+bx+c$ where $a=1$
#
# ### **1.** If we find $r$ and $s$ with sum $-b$ and product $c$ then $x^2+bx+c = (x-r)(x-s)$ and these are all the possible roots
# ### **2.** the sum of two numbers will be **$-b$** if they are $-\frac{b}{2}\pm u$
# ### **3.** their product will be $c$ when $\frac{b^2}{4}-u=c$
# ### **4.**  The square root will be always a valid value $u=\pm\sqrt{\frac{b^2}{4}-c}$
# ### **5.** Then $-\frac{b}{2}\pm u$ will work as both $r$ and $s$, and these will be roots
# ### **6.** So the the general from for each root will be $-\frac{b}{2}\pm\sqrt{\frac{b^2}{4}-c}$

# %%
def PSL(B,C): #Po Shen Loh's Method
  #Quadratic Equation x^2 + Bx + C = 0
  u = (((B**2)/4)-C)**0.5 #general expression for u
  mB = -B/2   #term -B without u
  ans = [mB + u,mB - u] 
  if (mB+u)==(mB-u):
    ans=mB+u
  return ans

# %%
def QEC(A,B,C): #Quadratic Equation Classic Method
  x1 = ((B*-1) + (B**2 - 4*A*C)**0.5)/2*A #First Root
  x2 = ((B*-1) - (B**2 - 4*A*C)**0.5)/2*A #Second root
  ans = [x1,x2]
  if x1==x2:
    ans = x1
  return ans

# %% [markdown]
# * $x^2=0$ Expanded from $x^2+0x+0=0$
#
# ### **Classic Method**
# Replacing the values in the quadratic formula, we obtain:
# $x=\frac{-b\pm\sqrt{b^2-4ac}}{2a}=\frac{0\pm\sqrt{0}}{2}=0$
#
# ### **Po Shen Loh's Method**
# The only roots existing for this polinomial term based on the method are:
# $r=0$  and $s=0$

# %%
print("Po Shen Loh Method:" ,PSL(0,0))
print("Classic Method:" ,QEC(1,0,0))
# Out:
# Po Shen Loh Method: 0.0
# Classic Method: 0.0

# %% [markdown]
# *   $(x-1)^2=0$ expanded from $x^2-2x+1=0$
#
# ### **Classic Method**
# $\frac{2\pm\sqrt{4-4}}{2}=1$
#
# ### **Po Shen Loh's Method**
# $\frac{-2}{2}\pm0$ , so $r=1$ , $s=1$ are the roots

# %%
print("Po Shen Loh Method:" ,PSL(-2,1))
print("Classic Method:" ,QEC(1,-2,1))
# Out:
# Po Shen Loh Method: 1.0
# Classic Method: 1.0

# %% [markdown]
# *   $x^2-1=0$ expanded from $x^2+0x-1=0$
#
# ### **Classic Method**
# $\frac{0\pm\sqrt{4}}{2}=\pm1$
#
# ### **Po Shen Loh's Method**
# $0\pm1$ , so $r=1$ and $s=-1$ are the roots

# %%
print("Po Shen Loh Method:" ,PSL(0,-1))
print("Classic Method:" ,QEC(1,0,-1))
# Out:
# Po Shen Loh Method: [1.0, -1.0]
# Classic Method: [1.0, -1.0]

# %% [markdown]
# *   $x^2+1=0$ expanded from $x^2+0x+1=0$
#
# ### **Classic Method**
# $\frac{0\pm\sqrt{-4}}{2}=\pm\frac{2i}{2}=\pm i$
#
# ### **Po Shen Loh's Method**
# $u=\pm\sqrt{\frac{0^2}{4}-1}=\pm\sqrt{-1}=\pm i$ , so $r=i$ and $s=-i$ are the roots

# %%
print("Po Shen Loh Method:" ,PSL(0,1))
print("Classic Method:" ,QEC(1,0,1))
# Out:
# Po Shen Loh Method: [(6.123233995736766e-17+1j), (-6.123233995736766e-17-1j)]
# Classic Method: [(6.123233995736766e-17+1j), (-6.123233995736766e-17-1j)]

# %% [markdown]
# # **3. Newton Fractals**
#
#
#
# ## **1.   $f(z)=z^2$**

# %%
#First Function 

def f(z): #original function in z terms
    return z ** 2

def df(z): #derivative of the function
    return  2*z

def newton_set1(z_c_r=0, z_c_i=0, zh = 5, zw=5, width=500, height=500, zoom=1,  niter=256):
    """ Fractals using newton-raphson """

    # Pixels array
    pixels = np.arange(width*height*3, dtype=np.uint32).reshape(height, width, 3)

    h = 1e-7 # step size for numerical derivative
    eps = 1e-3 # max error allowed

    # Bounding roots
    # Mathematically this function only has one root, that is r = 0 the only point whte it touches the x-axis
    r1 = 0
    # Color multiplication factor
    # NOTE: Increasing this darkens the image and lightens it otherwise
    multcol = 5

    for y in range(height):
            zy =   z_c_i+(((y-(height/2))/height)*zh*zoom)

            for x in range(width):
                zx = z_c_r+ (((x-(width/2))/width)*zw*zoom)

                # Mapping real -> complex plane
                z = complex(zx, zy)
                
                count = 0
                
                for i in range(niter):
                    # complex numerical derivative
                    dz = df(z)
                    if dz == 0:
                        break

                    count += 1
                    if count > 255:
                        break
                   
                    znext = z - f(z) / dz # Newton iteration

                    if abs(znext - z) < eps: # stop when close enough to any root
                        break
                    
                    z = znext

                # Pixels colored using the roots
                if abs(z-r1)<eps:
                    # color red
                    pixels[height-y-1,x] = (255 - count*multcol, 0, 0)
                else:   
                    pixels[height-y-1,x] = (0, 0, 0)
 
    return pixels

# %%
def displayf1(z_c_r=0, z_c_i=0, zh = 1, zw=1, width=500, height=500, zoom=1,  niter=256):
    """ Display a newton-raphson fractal """
    print("Z region from (",z_c_r+ (((0-(width/2))/width)*zw*zoom),",",z_c_i+(((0-(height/2))/height)*zh*zoom) ,") to (",z_c_r+ (((width-(width/2))/width)*zw*zoom),",",z_c_i+(((height-(height/2))/height)*zh*zoom),")")
    pimg = newton_set1(z_c_r=z_c_r, z_c_i=z_c_i, zh = zh, zw=zw, width=width, height=width, zoom=zoom,  niter=niter)
    plt.title('Newton Fractal f(z)=z^2')
    plt.xlabel("real"+"("+ str(z_c_r+ (((0-(width/2))/width)*zw*zoom))+","+str(z_c_r+ (((width-(width/2))/width)*zw*zoom))+")")
    plt.ylabel("imaginary"+"("+str(z_c_i+(((0-(height/2))/height)*zh*zoom))+","+str(z_c_i+(((height-(height/2))/height)*zh*zoom)) +")")
    plt.imshow(pimg)
    plt.show()

# %%
print("zoom out")
displayf1(zoom=0.010)
displayf1(zoom=0.020)
displayf1(zoom=0.030)
displayf1(zoom=0.040)
displayf1(zoom=0.050)
# Out:
# zoom out
# Z region from ( -0.005 , -0.005 ) to ( 0.005 , 0.005 )
# Z region from ( -0.01 , -0.01 ) to ( 0.01 , 0.01 )
# Z region from ( -0.015 , -0.015 ) to ( 0.015 , 0.015 )
# Z region from ( -0.02 , -0.02 ) to ( 0.02 , 0.02 )
# Z region from ( -0.025 , -0.025 ) to ( 0.025 , 0.025 )

# %%
print("zoom in")
displayf1(zoom=1/10)
displayf1(zoom=1/20)
displayf1(zoom=1/30)
displayf1(zoom=1/40)
displayf1(zoom=1/50)
displayf1(zoom=1/100)
displayf1(zoom=1/500)
displayf1(zoom=1/1000)
# Out:
# zoom in
# Z region from ( -0.05 , -0.05 ) to ( 0.05 , 0.05 )
# Z region from ( -0.025 , -0.025 ) to ( 0.025 , 0.025 )
# Z region from ( -0.016666666666666666 , -0.016666666666666666 ) to ( 0.016666666666666666 , 0.016666666666666666 )
# Z region from ( -0.0125 , -0.0125 ) to ( 0.0125 , 0.0125 )
# Z region from ( -0.01 , -0.01 ) to ( 0.01 , 0.01 )
# Z region from ( -0.005 , -0.005 ) to ( 0.005 , 0.005 )
# Z region from ( -0.001 , -0.001 ) to ( 0.001 , 0.001 )
# Z region from ( -0.0005 , -0.0005 ) to ( 0.0005 , 0.0005 )

# %% [markdown]
# ## **2.   $f(z)=(z-1)^2$**

# %%
#Second Function 

def f(z): #original function in z terms
    return (z-1) ** 2

def df(z): #derivative of the function
    return  2*(z-1)

def newton_set2(z_c_r=0, z_c_i=0, zh = 5, zw=5, width=500, height=500, zoom=1,  niter=256):
    """ Fractals using newton-raphson """

    # Pixels array
    pixels = np.arange(width*height*3, dtype=np.uint32).reshape(height, width, 3)

    h = 1e-7 # step size for numerical derivative
    eps = 1e-3 # max error allowed

    # Bounding roots
    # Mathematically this function only has one root, that is r = 0 the only point whte it touches the x-axis
    r1 = 1
    # Color multiplication factor
    # NOTE: Increasing this darkens the image and lightens it otherwise
    multcol = 5

    for y in range(height):
            zy =   z_c_i+(((y-(height/2))/height)*zh*zoom)

            for x in range(width):
                zx = z_c_r+ (((x-(width/2))/width)*zw*zoom)

                # Mapping real -> complex plane
                z = complex(zx, zy)
                
                count = 0
                
                for i in range(niter):
                    # complex numerical derivative
                    dz = df(z)
                    if dz == 0:
                        break

                    count += 1
                    if count > 255:
                        break
                   
                    znext = z - f(z) / dz # Newton iteration

                    if abs(znext - z) < eps: # stop when close enough to any root
                        break
                    
                    z = znext

                # Pixels colored using the roots
                if abs(z-r1)<eps:
                    # color red
                    pixels[height-y-1,x] = (255 - count*multcol, 0, 0)
                else:   
                    pixels[height-y-1,x] = (0, 0, 0)
 
    return pixels

# %%
def displayf2(z_c_r=0, z_c_i=0, zh = 1, zw=1, width=500, height=500, zoom=1,  niter=256):
    """ Display a newton-raphson fractal """
    print("Z region from (",z_c_r+ (((0-(width/2))/width)*zw*zoom),",",z_c_i+(((0-(height/2))/height)*zh*zoom) ,") to (",z_c_r+ (((width-(width/2))/width)*zw*zoom),",",z_c_i+(((height-(height/2))/height)*zh*zoom),")")
    pimg = newton_set2(z_c_r=z_c_r, z_c_i=z_c_i, zh = zh, zw=zw, width=width, height=width, zoom=zoom,  niter=niter)
    plt.title('Newton Fractal f(z)=(z-1)^2')
    plt.xlabel("real"+"("+ str(z_c_r+ (((0-(width/2))/width)*zw*zoom))+","+str(z_c_r+ (((width-(width/2))/width)*zw*zoom))+")")
    plt.ylabel("imaginary"+"("+str(z_c_i+(((0-(height/2))/height)*zh*zoom))+","+str(z_c_i+(((height-(height/2))/height)*zh*zoom)) +")")
    plt.imshow(pimg)
    plt.show()

# %%
print("zoom out")
displayf2(zoom=1)
displayf2(zoom=2)
displayf2(zoom=3)
displayf2(zoom=4)
displayf2(zoom=5)
# Out:
# zoom out
# Z region from ( -0.5 , -0.5 ) to ( 0.5 , 0.5 )
# Z region from ( -1.0 , -1.0 ) to ( 1.0 , 1.0 )
# Z region from ( -1.5 , -1.5 ) to ( 1.5 , 1.5 )
# Z region from ( -2.0 , -2.0 ) to ( 2.0 , 2.0 )
# Z region from ( -2.5 , -2.5 ) to ( 2.5 , 2.5 )

# %%
print("zoom in")
displayf2(zoom=1)
displayf2(zoom=1/2)
displayf2(zoom=1/3)
displayf2(zoom=1/4)
displayf2(zoom=1/5)
displayf2(zoom=1/10)
displayf2(zoom=1/100)
displayf2(zoom=1/1000)
# Out:
# zoom in
# Z region from ( -0.5 , -0.5 ) to ( 0.5 , 0.5 )
# Z region from ( -0.25 , -0.25 ) to ( 0.25 , 0.25 )
# Z region from ( -0.16666666666666666 , -0.16666666666666666 ) to ( 0.16666666666666666 , 0.16666666666666666 )
# Z region from ( -0.125 , -0.125 ) to ( 0.125 , 0.125 )
# Z region from ( -0.1 , -0.1 ) to ( 0.1 , 0.1 )
# Z region from ( -0.05 , -0.05 ) to ( 0.05 , 0.05 )
# Z region from ( -0.005 , -0.005 ) to ( 0.005 , 0.005 )
# Z region from ( -0.0005 , -0.0005 ) to ( 0.0005 , 0.0005 )

# %% [markdown]
# ## **3.   $f(z)=z^2-1$**

# %%
#Third Function 

def f(z): #original function in z terms
    return (z**2)-1

def df(z): #derivative of the function
    return  2*z

def newton_set3(z_c_r=0, z_c_i=0, zh = 5, zw=5, width=500, height=500, zoom=1,  niter=256):
    """ Fractals using newton-raphson """

    # Pixels array
    pixels = np.arange(width*height*3, dtype=np.uint32).reshape(height, width, 3)

    h = 1e-7 # step size for numerical derivative
    eps = 1e-3 # max error allowed

    # Bounding roots
    # Mathematically this function only has one root, that is r = 0 the only point whte it touches the x-axis
    r1 = 1.0
    r2 = -1.0
    r3 = 0
    # Color multiplication factor
    # NOTE: Increasing this darkens the image and lightens it otherwise
    multcol = 3

    for y in range(height):
            zy =   z_c_i+(((y-(height/2))/height)*zh*zoom)

            for x in range(width):
                zx = z_c_r+ (((x-(width/2))/width)*zw*zoom)

                # Mapping real -> complex plane
                z = complex(zx, zy)
                
                count = 0
                
                for i in range(niter):
                    # complex numerical derivative
                    dz = df(z)
                    if dz == 0:
                        break

                    count += 1
                    if count > 255:
                        break
                   
                    znext = z - f(z) / dz # Newton iteration

                    if abs(znext - z) < eps: # stop when close enough to any root
                        break
                    
                    z = znext

                # Pixels colored using the roots
                if abs(z-r1)<eps:
                    
                    pixels[height-y-1,x] = (0,130 , 255 - count*multcol)
                elif abs(z-r2)<=eps:
                    
                    pixels[height-y-1,x] = (255 - count*multcol,165 ,0)
                else:   
                    pixels[height-y-1,x] = (0, 80, 0 + count*multcol)
 
    return pixels

# %%
def displayf3(z_c_r=0, z_c_i=0, zh = 1, zw=1, width=500, height=500, zoom=1,  niter=256):
    """ Display a newton-raphson fractal """
    print("Z region from (",z_c_r+ (((0-(width/2))/width)*zw*zoom),",",z_c_i+(((0-(height/2))/height)*zh*zoom) ,") to (",z_c_r+ (((width-(width/2))/width)*zw*zoom),",",z_c_i+(((height-(height/2))/height)*zh*zoom),")")
    pimg = newton_set3(z_c_r=z_c_r, z_c_i=z_c_i, zh = zh, zw=zw, width=width, height=width, zoom=zoom,  niter=niter)
    plt.title('Newton Fractal f(z)=(z-1)^2')
    plt.xlabel("real"+"("+ str(z_c_r+ (((0-(width/2))/width)*zw*zoom))+","+str(z_c_r+ (((width-(width/2))/width)*zw*zoom))+")")
    plt.ylabel("imaginary"+"("+str(z_c_i+(((0-(height/2))/height)*zh*zoom))+","+str(z_c_i+(((height-(height/2))/height)*zh*zoom)) +")")
    plt.imshow(pimg)
    plt.show()

# %%
print("zoom out")
displayf3(zoom=1)
displayf3(zoom=2)
displayf3(zoom=3)
displayf3(zoom=4)
displayf3(zoom=5)
# Out:
# zoom out
# Z region from ( -0.5 , -0.5 ) to ( 0.5 , 0.5 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -1.0 , -1.0 ) to ( 1.0 , 1.0 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -1.5 , -1.5 ) to ( 1.5 , 1.5 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -2.0 , -2.0 ) to ( 2.0 , 2.0 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -2.5 , -2.5 ) to ( 2.5 , 2.5 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
print("zoom in")
displayf3(zoom=1)
displayf3(zoom=1/2)
displayf3(zoom=1/3)
displayf3(zoom=1/4)
displayf3(zoom=1/5)
displayf3(zoom=1/10)
displayf3(zoom=1/100)
displayf3(zoom=1/1000)
# Out:
# zoom in
# Z region from ( -0.5 , -0.5 ) to ( 0.5 , 0.5 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -0.25 , -0.25 ) to ( 0.25 , 0.25 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -0.16666666666666666 , -0.16666666666666666 ) to ( 0.16666666666666666 , 0.16666666666666666 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -0.125 , -0.125 ) to ( 0.125 , 0.125 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -0.1 , -0.1 ) to ( 0.1 , 0.1 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -0.05 , -0.05 ) to ( 0.05 , 0.05 )
# ...

# %% [markdown]
# ## **4.   $f(z)=z^2+1$**

# %%
#Fourth Function 

def f(z): #original function in z terms
    return (z**2)+1

def df(z): #derivative of the function
    return  2*z

def newton_set4(z_c_r=0, z_c_i=0, zh = 5, zw=5, width=500, height=500, zoom=1,  niter=256):
    """ Fractals using newton-raphson """

    # Pixels array
    pixels = np.arange(width*height*3, dtype=np.uint32).reshape(height, width, 3)

    h = 1e-7 # step size for numerical derivative
    eps = 1e-3 # max error allowed

    # Bounding roots
    # Mathematically this function only has one root, that is r = 0 the only point whte it touches the x-axis
    r1 = complex(0,1*1)
    r2 = complex(0,-1*1)
    # Color multiplication factor
    # NOTE: Increasing this darkens the image and lightens it otherwise
    multcol = 5

    for y in range(height):
            zy =   z_c_i+(((y-(height/2))/height)*zh*zoom)

            for x in range(width):
                zx = z_c_r+ (((x-(width/2))/width)*zw*zoom)

                # Mapping real -> complex plane
                z = complex(zx, zy)
                
                count = 0
                
                for i in range(niter):
                    # complex numerical derivative
                    dz = df(z)
                    if dz == 0:
                        break

                    count += 1
                    if count > 255:
                        break
                   
                    znext = z - f(z) / dz # Newton iteration

                    if abs(znext - z) < eps: # stop when close enough to any root
                        break
                    
                    z = znext

                # Pixels colored using the roots
                if abs(z-r1)<eps:
                    
                    (0,130 , 255 - count*multcol)
                elif abs(z-r2)<=eps:
                    
                    pixels[height-y-1,x] = (0, 0, 255 - count*multcol)
                else:   
                     pixels[height-y-1,x] = (255 - count*multcol,0 ,0)
 
    return pixels

# %%
def displayf4(z_c_r=0, z_c_i=0, zh = 1, zw=1, width=500, height=500, zoom=1,  niter=256):
    """ Display a newton-raphson fractal """
    print("Z region from (",z_c_r+ (((0-(width/2))/width)*zw*zoom),",",z_c_i+(((0-(height/2))/height)*zh*zoom) ,") to (",z_c_r+ (((width-(width/2))/width)*zw*zoom),",",z_c_i+(((height-(height/2))/height)*zh*zoom),")")
    pimg = newton_set4(z_c_r=z_c_r, z_c_i=z_c_i, zh = zh, zw=zw, width=width, height=width, zoom=zoom,  niter=niter)
    plt.title('Newton Fractal f(z)=(z-1)^2')
    plt.xlabel("real"+"("+ str(z_c_r+ (((0-(width/2))/width)*zw*zoom))+","+str(z_c_r+ (((width-(width/2))/width)*zw*zoom))+")")
    plt.ylabel("imaginary"+"("+str(z_c_i+(((0-(height/2))/height)*zh*zoom))+","+str(z_c_i+(((height-(height/2))/height)*zh*zoom)) +")")
    plt.imshow(pimg)
    plt.show()

# %%
print("zoom out")
displayf3(zoom=0.000000000000000001)
displayf3(zoom=0.00000000000000002)
displayf3(zoom=0.0000000000000003)
displayf3(zoom=0.000000000000004)
displayf3(zoom=0.00000000000005)
# Out:
# zoom out
# Z region from ( -5e-19 , -5e-19 ) to ( 5e-19 , 5e-19 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -1e-17 , -1e-17 ) to ( 1e-17 , 1e-17 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -1.5e-16 , -1.5e-16 ) to ( 1.5e-16 , 1.5e-16 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -2e-15 , -2e-15 ) to ( 2e-15 , 2e-15 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -2.5e-14 , -2.5e-14 ) to ( 2.5e-14 , 2.5e-14 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
print("zoom in")
displayf3(zoom=1)
displayf3(zoom=1/20)
displayf3(zoom=1/300)
displayf3(zoom=1/4000)
displayf3(zoom=1/50000)
displayf3(zoom=1/100000)
displayf3(zoom=1/1000000)
displayf3(zoom=1/10000000)
# Out:
# zoom in
# Z region from ( -0.5 , -0.5 ) to ( 0.5 , 0.5 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -0.025 , -0.025 ) to ( 0.025 , 0.025 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -0.0016666666666666668 , -0.0016666666666666668 ) to ( 0.0016666666666666668 , 0.0016666666666666668 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -0.000125 , -0.000125 ) to ( 0.000125 , 0.000125 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -1e-05 , -1e-05 ) to ( 1e-05 , 1e-05 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -5e-06 , -5e-06 ) to ( 5e-06 , 5e-06 )
# ...

# %% [markdown]
# # **4. Newton Iterations**
#
#
#
# ## **1.   $f(z)=z^2$**
#
#
# *  Iterations from $20.0+0.0j$

# %%
def f(z): #original function in z terms
    return z**2

def df(z): #derivative of the function
    return  2*z

z=20.0 + 0.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=20.0 + 0.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# *  Iterations from $-20.0+0.0j$

# %%
z=-20.0 + 0.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=-20.0 + 0.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# *   iterations from $0.0+20.0j$

# %%
z=0.0 + 20.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=0.0 + 20.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# *   Iterations from $0.0-20.0j$

# %%
z=0.0 - 20.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=0.0 - 20.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# ## **2.   $f(z)=(z-1)^2$**
#
# *  Iterations from $20.0+0.0j$

# %%
def f(z): #original function in z terms
    return (z-1)**2

def df(z): #derivative of the function
    return  2*(z-1)

z=20.0 + 0.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=20.0 + 0.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# *  Iterations from $-20.0+0.0j$

# %%
z=-20.0 + 0.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=-20.0 + 0.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# *   iterations from $0.0+20.0j$

# %%
z=0.0 + 20.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=0.0 + 20.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# *   Iterations from $0.0-20.0j$

# %%
z=0.0 - 20.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=0.0 - 20.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# ## **3.   $f(z)=z^2-1$**
#
# *  Iterations from $20.0+0.0j$

# %%
def f(z): #original function in z terms
    return z**2-1

def df(z): #derivative of the function
    return  2*z
z=20.0 + 0.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=20.0 + 0.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# *  Iterations from $-20.0+0.0j$

# %%
z=-20.0 + 0.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=0.0 - 20.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# *   iterations from $0.0+20.0j$

# %%
z=-0.0 + 20.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=0.0 - 20.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# *   iterations from $0.0-20.0j$

# %%
z=-0.0 - 20.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=0.0 - 20.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# ## **4.   $f(z)=z^2+1$**
#
# *  Iterations from $20.0+0.0j$

# %%
def f(z): #original function in z terms
    return z**2+1

def df(z): #derivative of the function
    return  2*z

z=20.0 + 0.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=20.0 + 0.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# *  Iterations from $-20.0+0.0j$

# %%
z=-20.0 + 0.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=0.0 - 20.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# *  Iterations from $0.0+20.0j$

# %%
z=-0.0 + 20.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=0.0 - 20.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# *  Iterations from $0.0-20.0j$

# %%
z=-0.0 - 20.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=0.0 - 20.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# # **4. Newton Iterations on diagonals**
#
# ## **1.   $f(z)=z^2$**
# *  Iterations from $20.0+20.0j$

# %%
def f(z): #original function in z terms
    return (z**2)

def df(z): #derivative of the function
    return  2*z

z=20.0 + 20.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=20.0 + 20.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# *  Iterations from $20.0-20.0j$

# %%
z=20.0 - 20.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=-20.0 + 0.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# *  Iterations from $-20.0+20.0j$

# %%
z=-20.0 + 20.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=-20.0 + 0.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# *  Iterations from $-20.0-20.0j$

# %%
z=-20.0 - 20.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=-20.0 + 0.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# ## **2.   $f(z)=(z-1)^2$**
#
# *  Iterations from $20.0+20.0j$

# %%
def f(z): #original function in z terms
    return (z-1)**2

def df(z): #derivative of the function
    return  2*(z-1)

z=20.0 + 20.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=20.0 + 20.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# *  Iterations from $20.0-20.0j$

# %%
z=-20.0 - 20.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=-20.0 + 0.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# *  Iterations from $-20.0+20.0j$

# %%
z=-20.0 + 20.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=-20.0 + 0.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# *  Iterations from $-20.0-20.0j$

# %%
z=-20.0 - 20.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=-20.0 + 0.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# ## **3.   $f(z)=z^2-1$**
#
# *  Iterations from $20.0+20.0j$

# %%
def f(z): #original function in z terms
    return z**2-1

def df(z): #derivative of the function
    return  2*z

z=20.0 + 20.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=20.0 + 20.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# *  Iterations from $20.0-20.0j$

# %%
z=20.0 - 20.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=-20.0 + 0.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# *  Iterations from $-20.0+20.0j$

# %%
z=-20.0 + 20.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=-20.0 + 0.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# *  Iterations from $-20.0-20.0j$

# %%
z=-20.0 - 20.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=-20.0 + 0.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# ## **4.   $f(z)=z^2+1$**
#
# *  Iterations from $20.0+20.0j$

# %%
def f(z): #original function in z terms
    return z**2+1

def df(z): #derivative of the function
    return  2*z

z=20.0 + 20.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=20.0 + 20.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# *  Iterations from $20.0-20.0j$

# %%
z=-20.0 - 20.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=-20.0 + 0.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# *  Iterations from $-20.0+20.0j$

# %%
z=-20.0 + 20.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=-20.0 + 0.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# *  Iterations from $-20.0-20.0j$

# %%
z=-20.0 - 20.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=-20.0 + 0.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()
